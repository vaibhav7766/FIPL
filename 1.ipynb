# %%
from PIL import Image
import numpy as np

# %%
url=r"C:\Users\vaibh\OneDrive\Desktop\Wallpapers\Genshin-s-Pistol-unveils-all-Fatui-Harbingers-in-storyline-teaser.png"
img=Image.open(url)
print(type(img))
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
img.show()

# %%
print(img.format)
print(img.mode)
# Out:
# PNG
# RGB

# %%
img1=np.asarray(img)
print(type(img1))
img.size
# Out:
# <class 'numpy.ndarray'>
# (1920, 1080)

# %%
img1.shape,img1.size,type(img1)
# Out:
# ((1080, 1920, 3), 6220800, numpy.ndarray)

# %%
img1
# Out:
# array([[[ 76, 131, 175],
#         [ 76, 131, 175],
#         [ 77, 130, 175],
#         ...,
#         [ 96, 163, 200],
#         [ 96, 163, 200],
#         [ 96, 163, 200]],
#
#        [[ 76, 131, 175],
#         [ 76, 131, 175],
#         [ 77, 130, 175],
#         ...,
#         [ 96, 163, 200],
#         [ 96, 163, 200],
#         [ 96, 163, 200]],
#
#        [[ 76, 131, 175],
#         [ 76, 131, 175],
#         [ 77, 130, 175],
#         ...,
#         [ 96, 163, 200],
#         [ 96, 163, 200],
#         [ 96, 163, 200]],
#
#        ...,
#
#        [[233, 249, 254],
#         [233, 249, 254],
#         [233, 249, 254],
#         ...,
#         [245, 255, 255],
#         [245, 255, 255],
#         [245, 255, 255]],
#
#        [[233, 249, 254],
#         [233, 249, 254],
#         [233, 249, 254],
#         ...,
#         [245, 255, 255],
#         [245, 255, 255],
#         [245, 255, 255]],
#
#        [[233, 249, 254],
#         [233, 249, 254],
#         [233, 249, 254],
# ...

# %%
from skimage import io,img_as_float,img_as_ubyte
import numpy as np
import matplotlib.pyplot as plt

# %%
image=img_as_float(io.imread(r"C:\Users\vaibh\OneDrive\Desktop\Wallpapers\Genshin-s-Pistol-unveils-all-Fatui-Harbingers-in-storyline-teaser.png"))
print(image)
# Out:
# [[[0.29803922 0.51372549 0.68627451]
#   [0.29803922 0.51372549 0.68627451]
#   [0.30196078 0.50980392 0.68627451]
#   ...
#   [0.37647059 0.63921569 0.78431373]
#   [0.37647059 0.63921569 0.78431373]
#   [0.37647059 0.63921569 0.78431373]]
#
#  [[0.29803922 0.51372549 0.68627451]
#   [0.29803922 0.51372549 0.68627451]
#   [0.30196078 0.50980392 0.68627451]
#   ...
#   [0.37647059 0.63921569 0.78431373]
#   [0.37647059 0.63921569 0.78431373]
#   [0.37647059 0.63921569 0.78431373]]
#
#  [[0.29803922 0.51372549 0.68627451]
#   [0.29803922 0.51372549 0.68627451]
#   [0.30196078 0.50980392 0.68627451]
#   ...
#   [0.37647059 0.63921569 0.78431373]
#   [0.37647059 0.63921569 0.78431373]
#   [0.37647059 0.63921569 0.78431373]]
#
#  ...
#
#  [[0.91372549 0.97647059 0.99607843]
#   [0.91372549 0.97647059 0.99607843]
#   [0.91372549 0.97647059 0.99607843]
#   ...
#   [0.96078431 1.         1.        ]
#   [0.96078431 1.         1.        ]
#   [0.96078431 1.         1.        ]]
#
# ...

# %%
image8byte=img_as_ubyte(image)
print(image8byte)
plt.imshow(image8byte)
# Out:
# [[[ 76 131 175]
#   [ 76 131 175]
#   [ 77 130 175]
#   ...
#   [ 96 163 200]
#   [ 96 163 200]
#   [ 96 163 200]]
#
#  [[ 76 131 175]
#   [ 76 131 175]
#   [ 77 130 175]
#   ...
#   [ 96 163 200]
#   [ 96 163 200]
#   [ 96 163 200]]
#
#  [[ 76 131 175]
#   [ 76 131 175]
#   [ 77 130 175]
#   ...
#   [ 96 163 200]
#   [ 96 163 200]
#   [ 96 163 200]]
#
#  ...
#
#  [[233 249 254]
#   [233 249 254]
#   [233 249 254]
#   ...
#   [245 255 255]
#   [245 255 255]
#   [245 255 255]]
#
#  [[233 249 254]
#   [233 249 254]
#   [233 249 254]
#   ...
#   [245 255 255]
#   [245 255 255]
#   [245 255 255]]
#
#  [[233 249 254]
#   [233 249 254]
#   [233 249 254]
#   ...
#   [245 255 255]
#   [245 255 255]
#   [245 255 255]]]

# %%
import cv2
grey_img=cv2.imread(r"C:\Users\vaibh\OneDrive\Desktop\Wallpapers\Genshin-s-Pistol-unveils-all-Fatui-Harbingers-in-storyline-teaser.png",0)
color_img=cv2.imread(r"C:\Users\vaibh\OneDrive\Desktop\Wallpapers\Genshin-s-Pistol-unveils-all-Fatui-Harbingers-in-storyline-teaser.png",1)

# %%
print(type(grey_img))
print(type(color_img))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
plt.imshow(grey_img,"gray")
plt.title("Gray Image",fontsize=14)
plt.axis("on")
plt.subplot(2,1,2)
plt.imshow(color_img)
plt.title("Color Image",fontsize=14)
plt.axis("on")
# Out:
# (-0.5, 1919.5, 1079.5, -0.5)
