# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r"C:\Users\vaibh\OneDrive\Desktop\Wallpapers\778702.png",cv2.IMREAD_GRAYSCALE)

# %%
#Generate random Gaussian noise
mean=0
stddev=200
noise=np.zeros(img.shape,np.uint8)
cv2.randn(noise,mean,stddev)
# Out:
# array([[  0,  32,   0, ...,   0, 207,   0],
#        [  0,   0, 103, ...,  63, 100, 255],
#        [151, 115,   0, ...,   0,   0,   0],
#        ...,
#        [ 73,   3, 120, ...,   0,   0,  61],
#        [  0, 255,   0, ..., 102,   0,   0],
#        [  0,   0,   0, ...,  82,   0, 185]], dtype=uint8)

# %%
#adding noise to image
noisy_img=cv2.add(img,noise)
cv2.imwrite("Gauss_noisy_img.jpg",noisy_img)
# Out:
# True

# %%
kernel=np.ones((5,5),np.float64)/25
dst=cv2.filter2D(noisy_img,-1,kernel)

# %%
plt.subplot(121)
plt.imshow(noise,"gray")
plt.subplot(122)
plt.hist(noise.ravel(),256,[0,256])
plt.show()

# %%
plt.subplot(231), plt.imshow(img,"gray")
plt.subplot(232), plt.imshow(noisy_img,"gray")
plt.subplot(233), plt.imshow(dst,"gray"), plt.title("Averaging")
plt.subplot(234), plt.hist(img.ravel(),256,[0,256]), plt.title("hist of original")
plt.subplot(235), plt.hist(noisy_img.ravel(),256,[0,256]), plt.title("hist of noisy")
plt.subplot(236), plt.hist(dst.ravel(),256,[0,256]), plt.title("hist of reconstructed")
plt.show()

# %%
img = cv2.imread(r"C:\Users\vaibh\OneDrive\Desktop\FIPL\Gauss_noisy_img.jpg")
blur=cv2.blur(img,(5,5))

# %%
plt.subplot(131), plt.imshow(img,"gray"), plt.title("Original")
plt.xticks([]), plt.yticks([])
plt.subplot(132), plt.imshow(noisy_img,"gray"), plt.title("Noisy")
plt.xticks([]), plt.yticks([])
plt.subplot(133), plt.imshow(blur,"gray"), plt.title("Averaged Image")
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur=cv2.GaussianBlur(img,(5,5),0)
plt.subplot(121), plt.imshow(img), plt.title("Original")
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(blur), plt.title("Blurred")
plt.xticks([]), plt.yticks([])
plt.show()

# %%
gblur=cv2.GaussianBlur(noisy_img,(5,5),0)
plt.subplot(121), plt.imshow(img), plt.title("Original")
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(blur), plt.title("Blurred")
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur=cv2.GaussianBlur(img,(5,5),0)
plt.subplot(141), plt.imshow(img), plt.title("Original")
plt.xticks([]), plt.yticks([])
plt.subplot(142), plt.imshow(blur), plt.title("Blurred")
plt.xticks([]), plt.yticks([])
gblur=cv2.GaussianBlur(noisy_img,(5,5),0)
plt.subplot(143), plt.imshow(img), plt.title("Original")
plt.xticks([]), plt.yticks([])
plt.subplot(144), plt.imshow(blur), plt.title("Blurred")
plt.xticks([]), plt.yticks([])
plt.show()

# %%
median=cv2.medianBlur(img,5)
plt.subplot(121), plt.imshow(img), plt.title("Original")
# Out:
# (<Axes: title={'center': 'Original'}>,
# ...
#  Text(0.5, 1.0, 'Original'))
